# %%
import pandas as pd


path = '../resources/symbol_windows/btcusdt-kline.csv'
df = pd.read_csv(path)
df
# Out:
#                      timestamp    start_time   symbol interval  \
# 0          2023-04-06 20:56:00           NaN  btcusdt      NaN
# 1          2023-04-06 20:57:00           NaN  btcusdt      NaN
# 2          2023-04-06 20:58:00           NaN  btcusdt      NaN
# 3          2023-04-06 20:59:00           NaN  btcusdt      NaN
# 4          2023-04-06 21:00:00           NaN  btcusdt      NaN
# ...                        ...           ...      ...      ...
# 21521  2023-04-21 22:22:59.999  1.682116e+12  BTCUSDT       1m
# 21522  2023-04-21 22:23:59.999  1.682116e+12  BTCUSDT       1m
# 21523  2023-04-21 22:24:59.999  1.682116e+12  BTCUSDT       1m
# 21524  2023-04-21 22:25:59.999  1.682116e+12  BTCUSDT       1m
# 21525  2023-04-21 22:26:59.999  1.682116e+12  BTCUSDT       1m
#
#        first_trade_id  last_trade_id     open    close     high      low  \
# 0                 NaN            NaN  27975.0  27975.0  27986.6  27972.5
# ...

# %%
groups = df.resample('W')
groups
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13068/1150201543.py in <module>
# ----> 1 groups = df.resample('W')
#       2 groups
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10548         offset: TimedeltaConvertibleTypes | None = None,
#   10549     ) -> Resampler:
# > 10550         return super().resample(
#   10551             rule=rule,
#   10552             axis=axis,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8311
#    8312         axis = self._get_axis_number(axis)
# -> 8313         return get_resampler(
#    8314             self,
#    8315             freq=rule,
#
# ...
